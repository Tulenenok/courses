# %% [markdown]
# # Урок 1.7

# %%
import pandas as pd
import numpy as np

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
students = pd.read_csv('StudentsPerformance.csv')

# %%
students
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# #### Графики через pandas

# %%
students['math score'].hist()
# Out:
# <AxesSubplot:>

# %%
students.plot.scatter(x='math score', y='reading score')
# Out:
# <AxesSubplot:xlabel='math score', ylabel='reading score'>

# %% [markdown]
# #### Через seaborn

# %%
ax = sns.lmplot(x='math score', y='reading score', hue='gender', data=students)  # fit_reg=False, если хотим убрать прямую
ax.set_xlabels('Math score')
ax.set_ylabels('Reading score')

# %% [markdown]
# ### Домашняя работа

# %%
salary = pd.read_csv('income.csv')

# %%
salary
# Out:
#             income
# 2018-11-30      20
# 2018-12-31      60
# 2019-01-31     180
# 2019-02-28     380
# 2019-03-31     660

# %%
sns.lineplot(data=salary)
# Out:
# <AxesSubplot:>

# %%
salary.income.plot()
# Out:
# <AxesSubplot:>

# %%
plt.plot(salary.index, salary.income)

# %%
salary.plot(kind='line')
# Out:
# <AxesSubplot:>

# %%
salary.plot()
# Out:
# <AxesSubplot:>

# %%
salary['income'].plot()
# Out:
# <AxesSubplot:>

# %%
sns.lineplot(x=salary.index, y=salary.income)
# Out:
# <AxesSubplot:ylabel='income'>

# %%
df = pd.read_csv("dataset_209770_6.txt", sep=" ")

# %%
df
# Out:
#               x            y
# 0    992.982743  1398.694089
# 1    906.333723   715.613359
# 2   1495.507569   306.696999
# 3    990.107895  1407.477652
# 4    704.812511  1196.537920
# ..          ...          ...
# 65   408.148168  1012.057005
# 66   395.262559  1002.932379
# 67   994.816968  1407.494813
# 68   993.467559  1389.522157
# 69   498.568473  1516.420899
#
# [70 rows x 2 columns]

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.plot.scatter(x='x', y='y')
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
tsvetuechki = pd.read_csv('genome_matrix.csv', index_col=0)
tsvetuechki
# Out:
#           species0  species1  species2  species3  species4
# species0  0.536029  0.920292  0.679708  0.840606  0.430842
# species1  0.920292  0.862417  0.887593  0.769754  0.203214
# species2  0.679708  0.887593  0.595156  0.003435  0.096052
# species3  0.840606  0.769754  0.003435  0.458870  0.029251
# species4  0.430842  0.203214  0.096052  0.029251  0.642109

# %%
data = tsvetuechki.drop('species0', axis=1)
data
# Out:
#           species1  species2  species3  species4
# species0  0.920292  0.679708  0.840606  0.430842
# species1  0.862417  0.887593  0.769754  0.203214
# species2  0.887593  0.595156  0.003435  0.096052
# species3  0.769754  0.003435  0.458870  0.029251
# species4  0.203214  0.096052  0.029251  0.642109

# %%
g = sns.heatmap(data=tsvetuechki, cmap='viridis')
g.xaxis.set_ticks_position('top')
g.xaxis.set_tick_params(rotation=90)

# %%
heroes = pd.read_csv('dota_hero_stats.csv')
heroes
# Out:
#      Unnamed: 0 attack_type   id  legs  localized_name  \
# 0             0       Melee    1     2       Anti-Mage
# 1             1       Melee    2     2             Axe
# 2             2      Ranged    3     4            Bane
# 3             3       Melee    4     2     Bloodseeker
# 4             4      Ranged    5     2  Crystal Maiden
# ..          ...         ...  ...   ...             ...
# 112         112       Melee  114     2     Monkey King
# 113         113      Ranged  119     2     Dark Willow
# 114         114       Melee  120     2       Pangolier
# 115         115      Ranged  121     2      Grimstroke
# 116         116       Melee  129     2            Mars
#
#                              name primary_attr  \
# 0          npc_dota_hero_antimage          agi
# 1               npc_dota_hero_axe          str
# 2              npc_dota_hero_bane          int
# 3       npc_dota_hero_bloodseeker          agi
# 4    npc_dota_hero_crystal_maiden          int
# ...

# %%
heroes['count_roles'] = [int(i.count("'") / 2) for i in heroes['roles']]

# %%
heroes
# Out:
#      Unnamed: 0 attack_type   id  legs  localized_name  \
# 0             0       Melee    1     2       Anti-Mage
# 1             1       Melee    2     2             Axe
# 2             2      Ranged    3     4            Bane
# 3             3       Melee    4     2     Bloodseeker
# 4             4      Ranged    5     2  Crystal Maiden
# ..          ...         ...  ...   ...             ...
# 112         112       Melee  114     2     Monkey King
# 113         113      Ranged  119     2     Dark Willow
# 114         114       Melee  120     2       Pangolier
# 115         115      Ranged  121     2      Grimstroke
# 116         116       Melee  129     2            Mars
#
#                              name primary_attr  \
# 0          npc_dota_hero_antimage          agi
# 1               npc_dota_hero_axe          str
# 2              npc_dota_hero_bane          int
# 3       npc_dota_hero_bloodseeker          agi
# 4    npc_dota_hero_crystal_maiden          int
# ...

# %%
heroes.mean()
# Out:
# Unnamed: 0     58.00000
# id             60.00000
# legs            2.08547
# count_roles     4.00000
# dtype: float64

# %%
iris = pd.read_csv('iris.csv')
iris
# Out:
#      Unnamed: 0  sepal length  sepal width  petal length  petal width  species
# 0             0           5.1          3.5           1.4          0.2        0
# 1             1           4.9          3.0           1.4          0.2        0
# 2             2           4.7          3.2           1.3          0.2        0
# 3             3           4.6          3.1           1.5          0.2        0
# 4             4           5.0          3.6           1.4          0.2        0
# ..          ...           ...          ...           ...          ...      ...
# 145         145           6.7          3.0           5.2          2.3        2
# 146         146           6.3          2.5           5.0          1.9        2
# 147         147           6.5          3.0           5.2          2.0        2
# 148         148           6.2          3.4           5.4          2.3        2
# 149         149           5.9          3.0           5.1          1.8        2
#
# [150 rows x 6 columns]

# %%
sns.distplot(iris['petal length'])
# Out:
# C:\Users\nataa\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='petal length', ylabel='Density'>

# %%
sns.violinplot(y=iris["petal length"])
# Out:
# <AxesSubplot:ylabel='petal length'>

# %%
sns.pairplot(iris)
